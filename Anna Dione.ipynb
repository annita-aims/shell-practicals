# %% [markdown]
# width = 17
# height = 12.0
# delimiter = '.'
# a= width/2
# b= width/2.0
# c= height/3
# d = 1+2*5
# e = delimiter * 5
# a=8 et est de type int
# b=8.5 et est de type float
# c=4.0 et est de type float
# d=11 et est de type int
# e=..... et est de type str

# %%
width = 17
height = 12.0
delimiter = '.'
a= width/2
b= width/2.0
c= height/3
d = 1+2*5
e = delimiter * 5
print("a=",a, "et a pour type:", type(a) )
print("b=",b, "et a pour type:", type(b))
print("c=",c, "et a pour type:", type(c) )
print("d=",d, "et a pour type:", type(d) )
print("e=",e, "et a pour type:", type(e) )
# Out:
# a= 8.5 et a pour type: <class 'float'>
# b= 8.5 et a pour type: <class 'float'>
# c= 4.0 et a pour type: <class 'float'>
# d= 11 et a pour type: <class 'int'>
# e= ..... et a pour type: <class 'str'>

# %%
import math
print("pi=", math.pi)
r=int(input("Donner le rayon de la sphere: "))
vol= (4/3)*math.pi*r**3
print(vol)
# Out:
# pi= 3.141592653589793
# Donner le rayon de la sphere: 5
# 523.5987755982989

# %%
a= 1
b= 5.0
c="ten"
print("Le type de 1 est: ",type(1))
print("Le type de b est: ",type(b))
print("Le type de c est: ",type(c))
d= a+a
e=a+b
f=b+b
#g=b+c
h=c+c
print(d, e, f, h)
# Out:
# Le type de 1 est:  <class 'int'>
# Le type de b est:  <class 'float'>
# Le type de c est:  <class 'str'>
# 2 6.0 10.0 tenten

# %% [markdown]
# C'est l'addition de str avec un float qui donne une erreur. une surprise: on dirait l'addition entre un float et un int qui passe alors que c'est pas les memes types.

# %%
print(a*a)
print(a-a)
print(a/a)
print(a%a)
print(a<a)
print(a>a)
print(a<=a)
print(a>=a)
print(a==a,'\n')

print(a*b)
print(a-b)
print(a/b)
print(a%b)
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
print(a==b, '\n')


print(b*b)
print(b-b)
print(b/b)
print(b%b)
print(b<b)
print(b>b)
print(b<=b)
print(b>=b)
print(b==b, '\n')
#print(b*c)
#print(b-c)
#print(b%b)
#print(b<c)
#print(b>b)
#print(b<=b)
#print(b>=b)
#print(b==b, '\n')

print(c==c, '\n')
print(c%c)
# Out:
# 1
# 0
# 1.0
# 0
# False
# False
# True
# True
# True
#
# 5.0
# -4.0
# 0.2
# 1.0
# True
# False
# True
# False
# False
#
# 25.0
# 0.0
# 1.0
# 0.0
# False
# False
# True
# True
# True
#
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a4c1db449ebf> in <module>()
#      39
#      40 print(c==c, '\n')
# ---> 41 print(c%c)
#
# TypeError: not all arguments converted during string formatting

# %%
Toute operation entre float et str echoue. surprise: pour le str=str seul les operations de comparaison et l'addition marchent.
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int(x=0) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
# ...

# %%
help(float)
# Out:
# Help on class float in module builtins:
#
# class float(object)
#  |  float(x) -> floating point number
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(...)
#  |      float.__format__(format_spec) -> string
#  |
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getformat__(...) from builtins.type
# ...

# %%
Pour generer des nombres aleatoires python importe random d'abord avec (from random import random)
et pour generer on met rand(a,b) avec a la borne minimale et b l borne maximale
pour donner une delimitation en dehors de 0 et 1 sinin pour se restreindre a o et 1 on utilise random()
# Out:
#   File "<ipython-input-43-dc0c994a64c1>", line 1
#     Pour generer des nombres aleatoires python importe random d'abord avec (from random import random)
#                ^
# SyntaxError: invalid syntax

# %%
from random import random 
print(random())
# Out:
# 0.40446511142211217

# %%
import math
a=math.log10(42)
print("log10(42)= ", a, "et son type est: ", type(a))
print(math.floor(4))
print(math.floor(4.9))
len('anna')
b=123
len(str(b))
# Out:
# log10(42)=  1.6232492903979006 et son type est:  <class 'float'>
# 4
# 4
# 3

# %% [markdown]
# b=math.log10(-0.32)
# print("log10(-0.32)= ", b, "et son type est: ", type(b))
# donne erreur car log10 n'est pas defini pour les nombres negatifs
# math.floor(n) avec n entier retourne toujours l'entier car la fonction permet d'avoir l'entier qui lui est plus proche.
# Pour un float elle donne le chiffre avant la virgule.
# len() donne la longueur d'une chaine de caractere. Elle retourne la longueur.
# Pour determiner le nombre de chiffres dans un nombre on peut mettre len(str(nombre)).
